# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pydataset import data

# Use seaborn's load_dataset function to load the iris database to answer the following questions:
df = sns.load_dataset('iris')


# What does the distribution of petal lengths look like?
sns.histplot(df.petal_length, kde= True)


# Is there a relationship between petal length and petal width?
sns.relplot(x =df.petal_length, y = df.petal_width, data = df)
##positive correlation

# %%
# Would it be reasonable to predict species based on sepal width and sepal length? 
#For this, you'll visualize two numeric columns through the lense of a categorical column.
sns.relplot(x =df.sepal_length, y = df.sepal_width, data = df, col = df.species)

##you might be able to pick out the setosas but the versicolors and the virginicas might be harder

# %%
# Which features would be best used to predict species?
sns.relplot(x =df.petal_length, y = df.petal_width, data = df, col = df.species)

##the pedal with and length would be better to predict species because it is easier
##to see the differences in species based off of the sizes


sns.pairplot(data=df)

# %%
# Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column,
# and calculate summary statistics for each dataset. 
# What do you notice?

df = sns.load_dataset('anscombe')

df.info()
df.describe()

##everything is a float except for the first row
##there are 44 rows
df.groupby('dataset').describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# ...

# %%
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.
sns.relplot(x =df.x, y = df.y, data = df,col = df.dataset)

# %%
# Load the InsectSprays dataset from pydataset and read it's documentation.
# Create a boxplot that shows the effectiveness of the different insect sprays.
# df = data('InsectSprays', show_doc=True)
df = data('InsectSprays')
sns.boxplot(data=df, y='count', x = 'spray')
# Out:
# <AxesSubplot:xlabel='spray', ylabel='count'>

# %%
# Load the swiss dataset from pydataset and read it's documentation.
#Create visualizations to answer the following questions:
# df = data('swiss', show_doc=True)

df = data('swiss')

# %%
# Create an attribute named is_catholic that holds a boolean value of 
# whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
df['is_catholic'] = df.Catholic > 50
df
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# Does whether or not a province is Catholic influence fertility?

# sns.relplot(x = df.Fertility, y= df.is_catholic, data = df, col = df.is_catholic)
# df

# df_ctab = pd.crosstab(df.Fertility, df.is_catholic)

# plt.bar(df_ctab.true, df_ctab.false )
# plt.plot(the_answer.Fertility



# sns.heatmap(df_ctab, fmt='d', )





plt.subplot(1,2,1)
plt.bar(True, df.Fertility[df.is_catholic == True].mean())
plt.xticks([1],[True])



plt.subplot(1,2,2)
plt.ylim(0,80)
plt.bar(False, df.Fertility[df.is_catholic == False].mean())
plt.xticks([0],[False])

plt.show()
the_answer = df.groupby('is_catholic').agg('mean')
the_answer
# sns.heatmap(df_ctab, annot=True, fmt='d', cmap='Blues')

# sns.catplot(data=the_answer, y=the_answer.Fertility, kind= 'bar')
sns.boxplot(data=df , x='is_catholic', y = 'Fertility')
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %%
# What measure correlates most strongly with fertility?


sns.heatmap(df.corr(), cmap='Reds', annot=True)

#catholic
##examination and education have highest negative correlation
for col in df:
    print(col)
    sns.scatterplot(data=df, y='Fertility', x=col)
    
    plt.show()
# Out:
# Fertility
# Agriculture
# Examination
# Education
# Catholic
# Infant.Mortality
# is_catholic

# %%
# Load the chipotle dataset from SQL, 


from env import username, hostname, password
def get_db_url(username, hostname, password, db_name):
     return f'mysql+pymysql://{username}:{password}@{hostname}/{db_name}'
db_name = 'chipotle'
url = get_db_url(username, hostname, password, db_name)
query = '''
select * from orders;

'''
the_table = pd.read_sql(query, url)





the_table
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
# create a bar chart that shows the 4 most popular items and the revenue produced by each.

# the_table.item_price = the_table.item_price.str.replace('$', '')
# the_table.item_price = the_table.item_price.astype(float)
# the_table.drop(columns = ['choice_description'])
the_table = the_table.groupby('item_name').agg('sum').sort_values(by=['quantity'], ascending = False)


# sns.catplot(data=the_answer, y=the_answer['item_price'], x=[1,2,3,4], kind='bar')
plt.xticks(rotation=90)
plt.bar(height=the_answer['item_price'], x=the_answer.index)


# the_answer
# Out:
# <BarContainer object of 4 artists>

# %%
# Load the sleepstudy dataset from pydataset and read it's documentation. 
# df = data('sleepstudy',show_doc= True)
df = data('sleepstudy')
df
# Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant

df
sns.color_palette("coolwarm", as_cmap=True)
sns.relplot(data=df, x='Days', y='Reaction', kind='line',hue='Subject',  size="Subject", palette="hls")




# sns.relplot(data=df, x='Days', y=df['Reaction'].mean(), kind='line')
# line showing the average change in reaction time.
